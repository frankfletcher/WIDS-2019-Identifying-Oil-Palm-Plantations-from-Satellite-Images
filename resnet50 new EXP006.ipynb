# %%
from IPython.display import Markdown, display

from wid_config import WIDConfig
from wid_torch import *

import pandas as pd
import numpy as np
np.random.seed(42)
rng = np.random.default_rng(42)

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

from pathlib import Path
data_path = Path('./data')
data_dir = data_path / 'train_images'


import os
import pandas as pd
import torch
import torchvision.transforms as transforms
from torchvision.transforms import v2
from torch.utils.data import Dataset, DataLoader, Subset
from torchvision import models
import torch.nn as nn
import torch.optim as optim
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score

torch.manual_seed(2024)
# Out:
# data/traininglabels.csv data/testlabels.csv data/holdout.csv
# data/traininglabels.csv
# 2024-11-13 00:04 - WARNING - dropped 978 missing images
# 2024-11-13 00:04 - WARNING - dropped 0 missing images

# %% [markdown]
# ## Load Data

# %%
config = WIDConfig(verbose=True, model_name="resnet50")

# config.df = config.df.sample(n=1000, random_state=config.random_state)
# Out:
# data/traininglabels.csv data/testlabels.csv data/holdout.csv
# ### Test Data
#         image_id  has_oilpalm  score                   base_path
# 0  img_04925.jpg            0    1.0  data/leaderboard_test_data
# 1  img_04817.jpg            1    1.0  data/leaderboard_test_data
# 2  img_10358.jpg            0    1.0  data/leaderboard_test_data
# 3  img_06729.jpg            0    0.6  data/leaderboard_test_data
# 4  img_09008.jpg            0    1.0  data/leaderboard_test_data
# ### Test Data Distribution
# data/traininglabels.csv
# 2024-11-13 00:04 - WARNING - dropped 978 missing images
# ### Train Data
#         image_id  has_oilpalm  score          base_path
# 0  img_00001.jpg            0    1.0  data/train_images
# 1  img_00002.jpg            0    1.0  data/train_images
# 2  img_00007.jpg            0    1.0  data/train_images
# 3  img_00008.jpg            0    1.0  data/train_images
# 4  img_00009.jpg            0    1.0  data/train_images
# ### Train Data Distribution
# 2024-11-13 00:04 - WARNING - dropped 0 missing images
# ### Train Data after Oversampling
#         image_id  has_oilpalm  score                   base_path
# 0  img_08153.jpg            0    1.0           data/train_images
# 1  img_08343.jpg            0    1.0           data/train_images
# 2  img_03204.jpg            1    1.0  data/leaderboard_test_data
# 3  img_00811.jpg            0    1.0           data/train_images
# 4  img_03672.jpg            0    1.0           data/train_images
# ### Train Data Distribution after Oversampling
# ### Holdout Data
#             image_id  has_oilpalm   score                      base_path
# 0  img_050982017.jpg            1  1.0000  data/leaderboard_holdout_data
# 1  img_101882017.jpg            1  1.0000  data/leaderboard_holdout_data
# 2  img_109452017.jpg            1  0.8079  data/leaderboard_holdout_data
# 3  img_009842017.jpg            1  1.0000  data/leaderboard_holdout_data
# 4  img_083672017.jpg            1  1.0000  data/leaderboard_holdout_data
# ### Holdout Data Distribution

# %% [markdown]
# ## Instantiate wid_torch for PyTorch model 1

# %% [markdown]
# ## define the model

# %%
# base model
_model = models.resnet50(weights="ResNet50_Weights.IMAGENET1K_V2")

# rebuild the head to suit our purpose
# strucure 2048 --> 32 --> num_classes
_model.fc = nn.Sequential(
    nn.Linear(_model.fc.in_features, 32),
    nn.BatchNorm1d(32),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(32, config.num_classes),
)
resnet_50 = WIDTorch(config=config, model=_model)

# %%
resnet_50.train(freeze=5)
# Out:
# Training model...
# Model saved at epoch 1 (score)
# Epoch [1/100], Loss: 0.5699, Val Loss: 0.5488, Val ROC AUC: 0.7679
# Model saved at epoch 2 (score)
# Epoch [2/100], Loss: 0.5586, Val Loss: 0.5483, Val ROC AUC: 0.7709

# %%
resnet_50.train(freeze=False)
# Out:
# Training model...
# Model saved at epoch 3 (score)
# Epoch [3/100], Loss: 0.5833, Val Loss: 0.5625, Val ROC AUC: 0.7460
# Model saved at epoch 4 (score)
# Epoch [4/100], Loss: 0.5655, Val Loss: 0.5529, Val ROC AUC: 0.7554
# Model saved at epoch 5 (score)
# Epoch [5/100], Loss: 0.5625, Val Loss: 0.5512, Val ROC AUC: 0.7638
# Epoch [6/100], Loss: 0.5551, Val Loss: 0.5586, Val ROC AUC: 0.7564
# Epoch [7/100], Loss: 0.5558, Val Loss: 0.5641, Val ROC AUC: 0.7561
# Model saved at epoch 8 (score)
# Epoch [8/100], Loss: 0.5552, Val Loss: 0.5506, Val ROC AUC: 0.7673
# Model saved at epoch 9 (loss)
# Epoch [9/100], Loss: 0.5530, Val Loss: 0.5423, Val ROC AUC: 0.7671
# Model saved at epoch 10 (score)
# Epoch [10/100], Loss: 0.5525, Val Loss: 0.5484, Val ROC AUC: 0.7692
# Model saved at epoch 11 (loss)
# Epoch [11/100], Loss: 0.5520, Val Loss: 0.5456, Val ROC AUC: 0.7677
# Model saved at epoch 12 (loss)
# Epoch [12/100], Loss: 0.5507, Val Loss: 0.5451, Val ROC AUC: 0.7661
# Model saved at epoch 13 (score)
# Epoch [13/100], Loss: 0.5475, Val Loss: 0.5413, Val ROC AUC: 0.7743
# Epoch [14/100], Loss: 0.5512, Val Loss: 0.5423, Val ROC AUC: 0.7695
# Model saved at epoch 15 (score)
# Epoch [15/100], Loss: 0.5497, Val Loss: 0.5374, Val ROC AUC: 0.7756
# Epoch [16/100], Loss: 0.5468, Val Loss: 0.5429, Val ROC AUC: 0.7676
# Epoch [17/100], Loss: 0.5463, Val Loss: 0.5378, Val ROC AUC: 0.7712
# Epoch [18/100], Loss: 0.5425, Val Loss: 0.5376, Val ROC AUC: 0.7740
# Epoch [19/100], Loss: 0.5422, Val Loss: 0.5464, Val ROC AUC: 0.7661
# Epoch [20/100], Loss: 0.5463, Val Loss: 0.5407, Val ROC AUC: 0.7725
# Early stopping at epoch 20

# %%
resnet_50.plot_losses()

# %%
resnet_50.plot_scores()

# %% [markdown]
# ## Load the best model and make predictions on the test set

# %% [markdown]
# ### Early Stopped model

# %%
resnet_50.evaluate_holdout()
# Out:
# ## Holdout ROC AUC: `0.9874`
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.94      1089
#            1       0.94      0.95      0.94      1089
#
#     accuracy                           0.94      2178
#    macro avg       0.94      0.94      0.94      2178
# weighted avg       0.94      0.94      0.94      2178

# %% [markdown]
# ### Best Validation Loss Model

# %%
resnet_50.resume(_model, "Exp:6_Model:resnet50_epoch:15_vloss:0.5374_auc:0.7756_S.pth")
resnet_50.evaluate_holdout()
# Out:
# ## Holdout ROC AUC: `0.9893`
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95      1089
#            1       0.96      0.94      0.95      1089
#
#     accuracy                           0.95      2178
#    macro avg       0.95      0.95      0.95      2178
# weighted avg       0.95      0.95      0.95      2178

# %%
# resume(model, f"best_model epoch_{best_epoch} auc_{best_val_score:.4f}.pth")

# model.eval()
# correct = 0
# total = 0
# labels_list = []
# outputs_list = []

# with torch.no_grad():
#     for images, labels in test_loader:
#         images, labels = images.to(device), labels.to(device).float()
#         outputs = model(images)
#         # _, predicted = torch.max(outputs.data, 1)
#         preds = sigmoid(outputs)
#         total += labels.size(0)
#         correct += ((outputs.squeeze() > 0) == labels).sum().item()

#         labels_list.append(labels.cpu().numpy())
#         outputs_list.append(preds.cpu().numpy())

# auc = roc_auc_score(np.concatenate(labels_list), np.concatenate(outputs_list))

# print(f"Test Accuracy: {100 * correct / total:.2f}%")
# print(f"Test AUC:      {auc:.4f}")

# %% [markdown]
# ## Confusion Matrix

# %%
np.array(outputs_list) > 0.5
# Out:
# array([[ True],
#        [ True],
#        [ True],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

conf_matrix = confusion_matrix(labels_list, np.array(outputs_list) > 0.5)

sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
